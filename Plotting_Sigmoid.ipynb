# %% [markdown]
# <a href="https://colab.research.google.com/github/pranaya-mathur/Concepts-Deep-Learning/blob/master/Plotting_Sigmoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def sigmoid(x,w,b):
  return 1/(1+np.exp(-(w*x+b)))

# %%
sigmoid(1,0.5,0)
# Out:
# 0.6224593312018546

# %%
w = -1.1 #@param {type: "slider", min: -2, max: 2, step: 0.9}
b = 1.8  #@param {type: "slider", min: 0, max: 2, step: 0.9}
X = np.linspace(-10,10,100)
Y = sigmoid(X,w,b)
plt.plot(X,Y)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(Y)
# Out:
# numpy.ndarray

# %%
import seaborn as sns
sns.set()

# %%
def sigmoid_2d(x1,x2,w1,w2,b):
  
  return 1/(1+np.exp(-(w1*x1+w2*x2+b)))

# %%
sigmoid_2d(1,0,0.5,0,0)
# Out:
# 0.6224593312018546

# %%
from mpl_toolkits import mplot3d

# %%
X1 = np.linspace(-10,10,100)
X2 = np.linspace(-10,10,100)

XX1,XX2 = np.meshgrid(X1,X2)

print(X1.shape,X2.shape,XX1.shape,XX2.shape)
# Out:
# (100,) (100,) (100, 100) (100, 100)

# %%
W1 = 0.5
W2 = 0.5
b = 0

Y = sigmoid_2d(XX1,XX2,W1,W2,b)

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.plot_surface(XX1, XX2, Y, cmap='viridis')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y');
